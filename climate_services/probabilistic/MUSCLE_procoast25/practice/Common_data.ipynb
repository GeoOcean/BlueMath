# %%
import xarray as xr

# %%
ss_ds = xr.open_dataset('ds_ss_Oporto_codec_rolling_mean.nc').sel(time=slice("1979-01-01", "2018-12-31"))

ss_ds
# Out:
# <xarray.Dataset> Size: 351kB
# Dimensions:             (time: 14610)
# Coordinates:
#   * time                (time) datetime64[ns] 117kB 1979-01-01 ... 2018-12-31
# Data variables:
#     surge               (time) float64 117kB ...
#     surge_rolling_mean  (time) float64 117kB ...

# %%
waves_ds = xr.open_dataset('Waves_ERA5_Oporto.nc').sel(time=slice("1979-01-01", "2018-12-31"))
waves_ds
# Out:
# <xarray.Dataset> Size: 292kB
# Dimensions:  (time: 14610)
# Coordinates:
#   * time     (time) datetime64[ns] 117kB 1979-01-01 1979-01-02 ... 2018-12-31
# Data variables:
#     swh      (time) float32 58kB ...
#     pp1d     (time) float32 58kB ...
#     mwd      (time) float32 58kB ...
# Attributes:
#     Conventions:             CF-1.7
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_edition:            1
#     GRIB_subCentre:          0
#     history:                 2025-05-05T16:51 GRIB to CDM+CF via cfgrib-0.9.1...
#     institution:             European Centre for Medium-Range Weather Forecasts

# %%
waves_ds["ss"] = ss_ds["surge"]
waves_ds
# Out:
# <xarray.Dataset> Size: 409kB
# Dimensions:  (time: 14610)
# Coordinates:
#   * time     (time) datetime64[ns] 117kB 1979-01-01 1979-01-02 ... 2018-12-31
# Data variables:
#     swh      (time) float32 58kB ...
#     pp1d     (time) float32 58kB ...
#     mwd      (time) float32 58kB ...
#     ss       (time) float64 117kB ...
# Attributes:
#     Conventions:             CF-1.7
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_edition:            1
#     GRIB_subCentre:          0
#     history:                 2025-05-05T16:51 GRIB to CDM+CF via cfgrib-0.9.1...
#     institution:             European Centre for Medium-Range Weather Forecasts

# %%
waves_ds.to_netcdf('daily_predictand_1979_2018_Oporto.nc')
